# %% [markdown]
# ### EDA on House Price Dataset                       by Divyanshu

# %% [markdown]
# ## Exercise

# %% [markdown]
# For this exercise, you will be working with the [House Price Dataset](https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/code).
#
# Please grab the train.csv file from Kaggle and explore this dataset. You need to perform explroatory data analysis and see if there is any correlation between the variables and analyze the distribution of the dataset. The question is open-ended and basically you're asked to perform EDA.

# %% [markdown]
# 1- Write a summary of your findings in one page (e.g., summary statistics, plots) and submit the pdf file. Therefore, for part 3 of your assignment, you need to submit at least one jupyter notebook file and one pdf file.
#
#
# 2- Push your code and project to github and provide the link to your code here. Ensure that your github project is organized to at least couple of main folders, ensure that you have the README file as well:
#
# - Src
# - Data
# - Docs
# - Results
#
# Read this link for further info:  https://gist.github.com/ericmjl/27e50331f24db3e8f957d1fe7bbbe510

# %% [markdown]
# https://github.com/divyanshufialok99/HOUSE-DATSET-EDA.git

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency

hppd=pd.read_csv('train.csv')
hppd.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
hppd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
hppd.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
hppd.describe(include='object')
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1  ... GarageType GarageFinish  \
# count       1460         1460       1460  ...       1379         1379
# unique         3           25          9  ...          6            3
# top          Gtl        NAmes       Norm  ...     Attchd          Unf
# freq        1382          225       1260  ...        870          605
#
#        GarageQual GarageCond PavedDrive PoolQC  Fence MiscFeature SaleType  \
# count        1379       1379       1460      7    281          54     1460
# unique          5          5          3      3      4           4        9
# ...

# %%
mv=hppd.isnull().sum()
mv=mv[mv>0]
mv
mv.sort_values(inplace=True)
mv.plot.bar(color=['red'])
# Out:
# <Axes: >

# %%
hppd['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
sns.histplot(hppd['SalePrice'], color='blue', kde=True)
plt.title('Distribution of Sale Price')
plt.show()

# %%
correlationm = hppd.corr(numeric_only=True)
correlationm['SalePrice'].sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# ...

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(correlationm, cmap='coolwarm', annot=True, fmt='.2f')
plt.title("Correlation Heatmap")
plt.show()

# %%
k=10 #Top 10 highly correlated Features
cols=correlationm.nlargest(k,'SalePrice')['SalePrice'].index
cm=np.corrcoef(hppd[cols].values.T)
plt.figure(figsize=(10, 6))
sns.heatmap(cm, cmap='coolwarm', annot=True, fmt='.2f',xticklabels=cols.values, yticklabels=cols.values)
plt.title("Correlation Heatmap")
plt.show() #Gets to know about Multicollinearity. Shows GarageCars and GarageArea are also correlated to each other so we can choose one.

# %% [markdown]
# **Observations of HeatMap**
#
# The variables with the best correlation with SalePrice i.e the property's sale price in dollars. This is the target variable that you're trying to predict. are
# - OverallQual i.e Overall material and finish quality,
# - GrLivArea i.e Above grade (ground) living area square feet,
# - GarageCars i.e Size of garage in car capacity,
# - GarageArea i.e Size of garage in square feet,
# - TotalBsmtSF i.e Total square feet of basement area,
# - 1stFlrSF i.e First Floor square feet,
# - FullBath i.e Full bathrooms above grade,
# - TotRmsAbvGrd i.e Total rooms above grade (does not include bathrooms),
# - YearBuilt i.e Original construction date.

# %% [markdown]
# #### The hypotheses that we are going to cover for this dataset are :
#
# - Determine how Overall Material and Finish Quality affects the Property's Sale Price.
# - Determine if there is relation between Property's Sale Price and Above Grade (ground) Living Area Square Feet
# - Determine if Original Construction Date affects the Property's Sale Price
# - Determine how the Number of Sales have changed over the Years

# %% [markdown]
# #### 1) Determine how Overall Material and Finish Quality affects the Property's Sale Price.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(hppd['OverallQual'], kde=True, color='red')
plt.title('Distribution of Overall Material and Finish Quality')
plt.xlabel('Overall Quality')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 7))
sns.regplot(x=hppd['OverallQual'],y=hppd['SalePrice'], fit_reg=True, color='blue')
plt.title('Relationship between Sale Price and Overall Quality')
plt.xlabel('Overall Quality')
plt.ylabel('Sale Price')
plt.show()

# %%
corr1 = hppd['SalePrice'].corr(hppd['OverallQual'])
f'The Correlation between SalePrice and OverallQual: {corr1:.2f}'
# Out:
# 'The Correlation between SalePrice and OverallQual: 0.79'

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=hppd['OverallQual'], y=hppd['SalePrice'], palette='Set1')
plt.title('Sale Price vs. Overall Quality')
plt.xlabel('Overall Quality')
plt.ylabel('Sale Price')
plt.show()

# %%
overallqualprice = hppd.groupby('OverallQual')['SalePrice'].mean()
plt.figure(figsize=(10, 6))
sns.barplot(x=overallqualprice.index, y=overallqualprice.values, palette='Set1')
plt.title('Mean Sale Price for Each Overall Quality Category')
plt.xlabel('Overall Quality')
plt.ylabel('Mean Sale Price')
plt.show()

# %% [markdown]
# #### 2) Determine if there is relation between Property's Sale Price and Above Grade (ground) Living Area Square Feet.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(hppd['GrLivArea'], kde=True, color='Red')
plt.title('Distribution of Above Grade Living Area')
plt.xlabel('Above Grade Living Area (sqft)')
plt.show()

# %%
plt.figure(figsize=(10, 7))
sns.regplot(x=hppd['GrLivArea'],y=hppd['SalePrice'], fit_reg=True, color='Blue')
plt.title('Relationship between Sale Price and Grade Living Area Square Feet')
plt.xlabel('Ground Living Area')
plt.ylabel('Sale Price')
plt.show()

# %%
corr2 = hppd['SalePrice'].corr(hppd['GrLivArea'])
f'The Correlation between SalePrice and GrLivArea: {corr2:.2f}'
# Out:
# 'The Correlation between SalePrice and GrLivArea: 0.71'

# %% [markdown]
# **Relationship between Sale Price and Above Ground Living Area based on Overall Quality**

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=hppd['GrLivArea'], y=hppd['SalePrice'], hue=hppd['OverallQual'], palette='Set1')
plt.title('Sale Price vs. Above Ground Living Area Based On Quality')
plt.xlabel('Above Ground Living Area (sq. ft.)')
plt.ylabel('Sale Price')
plt.show()

# %% [markdown]
# #### 3) Determine if Original Construction Date affects the Property's Sale Price.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(hppd['YearBuilt'], kde=True, color='Red')
plt.title('Distribution of Original Construction Year')
plt.xlabel('Year Built')
plt.show()

# %%
plt.figure(figsize=(10, 7))
sns.regplot(x=hppd['YearBuilt'],y=hppd['SalePrice'], fit_reg=True, color='Blue')
plt.title('Relationship between Sale Price and Original Construction Date')
plt.xlabel('Year Built')
plt.ylabel('Sale Price')
plt.show()

# %%
corr3 = hppd['SalePrice'].corr(hppd['YearBuilt'])
f'The Correlation between SalePrice and YearBuilt: {corr3:.2f}'
# Out:
# 'The Correlation between SalePrice and YearBuilt: 0.52'

# %%
meanpricebyyear = hppd.groupby('YearBuilt')['SalePrice'].mean()
plt.figure(figsize=(10, 6))
meanpricebyyear.plot(color='Red')
plt.title('Mean Sale Price Over the Years')
plt.xlabel('Year Built')
plt.ylabel('Mean Sale Price')
plt.show()

# %% [markdown]
# #### 4) Determine how the Number of Sales have changed over the Years

# %%
yearly_count = hppd['YrSold'].value_counts().sort_index()
plt.subplot(1,2,1)
sns.barplot(x=yearly_count.index, y=yearly_count.values, palette="Set1")
plt.title('Bar Graph of Number of Sales in Each Year')
plt.xlabel('Year Built')
plt.ylabel('Number of Sales')
plt.xticks(rotation=90)

plt.subplot(1,2,2)
plt.pie(yearly_count, labels=yearly_count.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('Blues'))
plt.title('Proportion of Sales by Year')

plt.suptitle("Number of Sales in Each Year")
plt.show()

# %%
plt.figure(figsize=(10, 6))
yearly_count.plot(color='Red')
plt.title('Number of Sales Over the Years')
plt.xlabel('Year Built')
plt.ylabel('Number of Sales')
plt.show()

# %% [markdown]
# **Relationship between Sale Price by LotShape and LandContour**

# %%
plt.figure(figsize=(12, 6))
ax = sns.barplot(data=hppd, x='LotShape', y='SalePrice', hue='LandContour', palette='Set1')
plt.title('Sale Price by LotShape and LandContour')
plt.xlabel('LotShape')
plt.ylabel('Sale Price')
plt.legend(title='LandContour')
plt.xticks(rotation=0)
plt.show()

# %%
bin_edges = [0, 100000, 200000, 800000]
bin_labels = ['Low', 'Medium', 'High']
hppd['SalePriceCategory'] = pd.cut(hppd['SalePrice'], bins=bin_edges, labels=bin_labels)
contingency_table = pd.crosstab(index=hppd['LotShape'], columns=hppd['LandContour'], values=hppd['SalePriceCategory'], aggfunc='count')

chi2, p, _, _ = chi2_contingency(contingency_table)
print(f'Chi-squared value: {chi2:.2f}')
print(f'p-value: {p:.15f}')
# Out:
# Chi-squared value: 78.99
# p-value: 0.000000000000256
